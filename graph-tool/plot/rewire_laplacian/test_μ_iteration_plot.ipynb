# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
Node = 1000

m = 2

times = 100

net_list = ["SF", "ER"]

# %%
count_list = [1, 2, 5, 10, 20]
recalculate_list = [1000, 500, 200, 100, 50]
name_list = ["1 × 1000", "2 × 500", "5 × 200", "10 × 100", "20 × 50"]

# %%
# 色のリスト
colors = ["red", "orange", "yellow", "green", "blue", "cyan", "purple", (0.03, 0.18, 0.42), (0.4, 0, 0.4)]

for net in net_list:
    
    plot_list = []
    
    for count, recalculate in zip(count_list, recalculate_list):
        save_path = f"~/o_t_hayashilab/complex_networks_2024/iteration_μ/{net}/c={count}_re={recalculate}.npy"
        plot_file = np.load(os.path.expanduser(save_path), allow_pickle=True)
       
        plot_list.append(plot_file)
        
    # Find the maximum length and the maximum y value for setting xlim and ylim
    min_val = min([plot.min() for plot in plot_list])
    max_len = max([len(plot.flatten()) for plot in plot_list])  # Max length of lists
    max_val = max([plot.max() for plot in plot_list])  # Max value in all lists
       
    # Plot each list from plot_list
    plt.figure(figsize=(10, 6))  # Adjust figure size
    for i in range(len(plot_list)):
        # Flatten the 2D array into 1D (if needed) and get the x-axis range
        y = plot_list[i].flatten()  # Convert 2D array to 1D
        x = range(len(y))  # Create x-axis values based on the length of y
        
        # Plot each set of data with corresponding label and color
        plt.plot(x, y, label=f"{net}:{name_list[i]}", color=colors[i % len(colors)])
    
    # Set the title, labels, and legend
    plt.xlabel("Iterations")
    plt.ylabel(r"$μ_{2}$")
    plt.legend()
    
    # Set x and y axis limits
    plt.xlim(0, max_len)  # x axis from 0 to max length of data
    plt.ylim(0, 0.6)      # y axis from 0 to the maximum value
    
    # Display the plot
    plt.show()

# %%
count_list = [50, 100, 200, 500, 1000]
recalculate_list = [20, 10, 5, 2, 1]
name_list = ["50 × 20", "100 × 10", "200 × 5", "500 × 2", "1000 × 1"]

# %%
# 色のリスト
colors = ["red", "orange", "yellow", "green", "blue", "cyan", "purple", (0.03, 0.18, 0.42), (0.4, 0, 0.4)]

for net in net_list:
    
    plot_list = []
    
    for count, recalculate in zip(count_list, recalculate_list):
        save_path = f"~/o_t_hayashilab/complex_networks_2024/iteration_μ/{net}/c={count}_re={recalculate}.npy"
        plot_file = np.load(os.path.expanduser(save_path), allow_pickle=True)
       
        plot_list.append(plot_file)
        
    # Find the maximum length and the maximum y value for setting xlim and ylim
    min_val = min([plot.min() for plot in plot_list])
    max_len = max([len(plot.flatten()) for plot in plot_list])  # Max length of lists
    max_val = max([plot.max() for plot in plot_list])  # Max value in all lists
       
    # Plot each list from plot_list
    plt.figure(figsize=(10, 6))  # Adjust figure size
    for i in range(len(plot_list)):
        # Flatten the 2D array into 1D (if needed) and get the x-axis range
        y = plot_list[i].flatten()  # Convert 2D array to 1D
        x = range(len(y))  # Create x-axis values based on the length of y
        
        # Plot each set of data with corresponding label and color
        plt.plot(x, y, label=f"{net}:{name_list[i]}", color=colors[i % len(colors)])
    
    # Set the title, labels, and legend
    plt.xlabel("Iterations")
    plt.ylabel(r"$μ_{2}$")
    plt.legend()
    
    # Set x and y axis limits
    plt.xlim(0, 20)  # x axis from 0 to max length of data
    plt.ylim(0, 0.6)      # y axis from 0 to the maximum value
    
    # Display the plot
    plt.show()

# %%
plot_list
# Out:
# [array([[0.31351166, 0.35743988, 0.37744528, 0.38746671, 0.40836592,
#          0.41107787, 0.41959978, 0.41590824, 0.42285815, 0.42013958,
#          0.41943267, 0.42746276, 0.42415903, 0.42820302, 0.43175241,
#          0.4333232 , 0.43852245, 0.43397241, 0.43804775, 0.44033828,
#          0.43945743, 0.43537251, 0.43772052, 0.43824914, 0.44112538,
#          0.44292618, 0.44210178, 0.44057783, 0.44248951, 0.43461653,
#          0.44008443, 0.43413504, 0.4368418 , 0.4382673 , 0.44105459,
#          0.43797129, 0.43929213, 0.43375018, 0.43360198, 0.43365176,
#          0.43769129, 0.43123725, 0.43417409, 0.43527989, 0.43546604,
#          0.43503362, 0.43502017, 0.4380745 , 0.43494402, 0.43488442,
#          0.43358515, 0.43161763, 0.42918688, 0.43531342, 0.43180571,
#          0.43348094, 0.43088437, 0.43229271, 0.43037494, 0.42799329,
#          0.42447536, 0.43014977, 0.42328797, 0.42421335, 0.42538231,
#          0.42435633, 0.42478889, 0.42666036, 0.42897849, 0.42424759,
#          0.4248202 , 0.42409805, 0.4264349 , 0.42233248, 0.42271633,
#          0.42157379, 0.41546448, 0.41925562, 0.4189231 , 0.42088502,
#          0.41720076, 0.41811509, 0.41562043, 0.41643989, 0.41843721,
#          0.41418895, 0.41379476, 0.41504193, 0.41329175, 0.41375227,
#          0.41162873, 0.41028812, 0.41094382, 0.41118007, 0.4077849 ,
#          0.41016073, 0.40979403, 0.41065892, 0.4065039 , 0.407538  ,
#          0.40835079]]),
#  array([[0.31351166, 0.35506155, 0.37966185, 0.39721607, 0.39060721,
#          0.38509653, 0.39153374, 0.40064903, 0.39900274, 0.40164767,
#          0.40794278, 0.39854412, 0.40337072, 0.40477059, 0.40843907,
#          0.4002874 , 0.39677902, 0.39715015, 0.4035931 , 0.3983253 ,
#          0.39874087, 0.39721068, 0.40115802, 0.3984383 , 0.3946476 ,
#          0.38890564, 0.39103106, 0.39394557, 0.39310722, 0.39129456,
#          0.383224  , 0.38828888, 0.38323506, 0.3799641 , 0.37970877,
#          0.38243372, 0.36908361, 0.37374245, 0.38087084, 0.37724345,
#          0.37294763, 0.37524428, 0.37279163, 0.37368066, 0.37123068,
#          0.37199382, 0.37269539, 0.36905497, 0.36945133, 0.36128741,
#          0.3669683 ]]),
#  array([[0.31351166, 0.34607824, 0.35739211, 0.35380675, 0.35488178,
#          0.361519  , 0.36014623, 0.36105475, 0.36150094, 0.35095653,
#          0.35292702, 0.34479616, 0.34707483, 0.34811868, 0.3448328 ,
#          0.34876971, 0.33321589, 0.34056632, 0.33444136, 0.33032646,
#          0.32326472]]),
#  array([[0.31351166, 0.32590625, 0.3354177 , 0.30850064, 0.32644685,
#          0.30757186, 0.31755037, 0.30352406, 0.31229167, 0.29700601,
#          0.2974835 ]]),
#  array([[0.31351166, 0.28677342, 0.27991947, 0.27724225, 0.27725352,
#          0.26641394]]),
#  array([[0.31351166, 0.40546927]])]
